# %%
import pandas as pd

# %%
customer_df = pd.read_csv('../customer-churn.csv')

# %%
customer_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
customer_df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
customer_df.describe
# Out:
# <bound method NDFrame.describe of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#transform the total charges column to numeric
customer_df['TotalCharges'] = pd.to_numeric(customer_df['TotalCharges'], errors='coerce')
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#Check for missing values in TotalCharges
customer_df['TotalCharges'].isna().sum()
# Out:
# np.int64(11)

# %%
#fix the missing totalCharges with 0
customer_df['TotalCharges'].fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_22006/703802920.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customer_df['TotalCharges'].fillna(0, inplace=True)

# %%
customer_df['TotalCharges'].isna().sum()
# Out:
# np.int64(0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=customer_df, x='Churn', y='TotalCharges')
plt.title('Total Charges vs Churn')
plt.xlabel('Churn')
plt.ylabel('Total Charges')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=customer_df, x='Churn', y='TotalCharges')
plt.title("Total Charges vs Churn (Violin Plot)")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=customer_df, x='TotalCharges', hue='Churn', kde=True, bins=30)
plt.title("Distribution of Total Charges by Churn")
plt.xlabel("Total Charges")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=customer_df, x='Churn', y='MonthlyCharges')
plt.title('Monthly Charges vs Churn')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=customer_df, x='gender', hue='Churn')
plt.title("Gender vs Churn Count")
plt.xlabel("Gender")
plt.ylabel("Number of Customers")
plt.show()

# %%
gender_churn_rate = (
    customer_df.groupby('gender')['Churn']
    .value_counts(normalize=True)
    .mul(100)
    .rename('percentage')
    .reset_index()
)

plt.figure(figsize=(8, 5))
sns.barplot(data=gender_churn_rate, x='gender', y='percentage', hue='Churn')
plt.title("Churn Rate (%) by Gender")
plt.ylabel("Percentage (%)")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=customer_df, x='TechSupport', hue='Churn')
plt.title("TechSupport vs Churn Count")
plt.xlabel("TechSupport")
plt.ylabel("Number of Customers")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=customer_df, x='PhoneService', hue='Churn', palette='Set2')
plt.title('Phone Service vs Churn')
plt.xlabel('Phone Service')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Pivot table for churn percentage
churn_contract = pd.crosstab(customer_df['Contract'], customer_df['Churn'])
churn_contract['Total'] = churn_contract.sum(axis=1)
churn_contract['Churn_Percentage'] = (churn_contract['Yes'] / churn_contract['Total']) * 100
churn_contract
# Out:
# Churn             No   Yes  Total  Churn_Percentage
# Contract
# Month-to-month  2220  1655   3875         42.709677
# One year        1307   166   1473         11.269518
# Two year        1647    48   1695          2.831858

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=churn_contract.index, y=churn_contract['Churn_Percentage'], palette='Set1')
plt.title('Churn Percentage by Contract Type')
plt.ylabel('Churn Percentage (%)')
plt.show()
# Out:
# /tmp/ipykernel_22006/847512184.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=churn_contract.index, y=churn_contract['Churn_Percentage'], palette='Set1')

# %%
# Crosstab for churn percentage
churn_security = pd.crosstab(customer_df['OnlineSecurity'], customer_df['Churn'])
churn_security['Total'] = churn_security.sum(axis=1)
churn_security['Churn_Percentage'] = (churn_security['Yes'] / churn_security['Total']) * 100
churn_security

plt.figure(figsize=(6,4))
sns.barplot(x=churn_security.index, y=churn_security['Churn_Percentage'], palette='Set1')
plt.title('Churn Percentage by Online Security')
plt.ylabel('Churn Percentage (%)')
plt.show()
# Out:
# /tmp/ipykernel_22006/1570696719.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=churn_security.index, y=churn_security['Churn_Percentage'], palette='Set1')

# %%
churn_tvStreaming = pd.crosstab(customer_df['StreamingTV'], customer_df['Churn'])
churn_tvStreaming['Total'] = churn_tvStreaming.sum(axis=1)
churn_tvStreaming['Churn_Percentage'] = (churn_tvStreaming['Yes'] / churn_tvStreaming['Total']) * 100
churn_tvStreaming

plt.figure(figsize=(6,4))
sns.barplot(x=churn_tvStreaming.index, y=churn_tvStreaming['Churn_Percentage'], palette='Set1')
plt.title('Churn Percentage by Streaming TV')
plt.ylabel('Churn Percentage (%)')
plt.show()
# Out:
# /tmp/ipykernel_22006/1551723549.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=churn_tvStreaming.index, y=churn_tvStreaming['Churn_Percentage'], palette='Set1')

# %%
plt.figure(figsize=(10,6))
sns.catplot(data=customer_df, x='Contract', hue='StreamingTV', col='Churn', kind='count', height=5, aspect=1)
plt.show()

# %%
# Crosstab for churn
churn_movies = pd.crosstab(customer_df['StreamingMovies'], customer_df['Churn'])
churn_movies['Total'] = churn_movies.sum(axis=1)
churn_movies['Churn_Percentage'] = (churn_movies['Yes'] / churn_movies['Total']) * 100
churn_movies
# Out:
# Churn                  No  Yes  Total  Churn_Percentage
# StreamingMovies
# No                   1847  938   2785         33.680431
# No internet service  1413  113   1526          7.404980
# Yes                  1914  818   2732         29.941435

# %%
plt.figure(figsize=(6,4))
ax = sns.barplot(x=churn_movies.index, y=churn_movies['Churn_Percentage'], palette='Set1')
plt.title('Churn Percentage by Streaming Movies')
plt.ylabel('Churn Percentage (%)')

# Optional: show percentages on bars
for i, v in enumerate(churn_movies['Churn_Percentage']):
    ax.text(i, v + 1, f"{v:.1f}%", ha='center')

plt.show()
# Out:
# /tmp/ipykernel_22006/1381573877.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=churn_movies.index, y=churn_movies['Churn_Percentage'], palette='Set1')

# %%
plt.figure(figsize=(10,6))
sns.catplot(data=customer_df, x='Contract', hue='StreamingMovies', col='Churn', kind='count', height=5, aspect=1)
plt.show()

# %%
# Crosstab for churn
churn_backup = pd.crosstab(customer_df['OnlineBackup'], customer_df['Churn'])
churn_backup['Total'] = churn_backup.sum(axis=1)
churn_backup['Churn_Percentage'] = (churn_backup['Yes'] / churn_backup['Total']) * 100
churn_backup
# Out:
# Churn                  No   Yes  Total  Churn_Percentage
# OnlineBackup
# No                   1855  1233   3088         39.928756
# No internet service  1413   113   1526          7.404980
# Yes                  1906   523   2429         21.531494

# %%
plt.figure(figsize=(6,4))
ax = sns.barplot(x=churn_backup.index, y=churn_backup['Churn_Percentage'], palette='Set2')
plt.title('Churn Percentage by Online Backup')
plt.ylabel('Churn Percentage (%)')

# Show percentages on bars
for i, v in enumerate(churn_backup['Churn_Percentage']):
    ax.text(i, v + 1, f"{v:.1f}%", ha='center')

plt.show()
# Out:
# /tmp/ipykernel_22006/4115202319.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=churn_backup.index, y=churn_backup['Churn_Percentage'], palette='Set2')

# %%
# Crosstab for churn
churn_paperless = pd.crosstab(customer_df['PaperlessBilling'], customer_df['Churn'])
churn_paperless['Total'] = churn_paperless.sum(axis=1)
churn_paperless['Churn_Percentage'] = (churn_paperless['Yes'] / churn_paperless['Total']) * 100
churn_paperless
# Out:
# Churn               No   Yes  Total  Churn_Percentage
# PaperlessBilling
# No                2403   469   2872         16.330084
# Yes               2771  1400   4171         33.565092

# %%
plt.figure(figsize=(6,4))
ax = sns.barplot(x=churn_paperless.index, y=churn_paperless['Churn_Percentage'], palette='Set2')
plt.title('Churn Percentage by Paperless Billing')
plt.ylabel('Churn Percentage (%)')

# Show percentages on bars
for i, v in enumerate(churn_paperless['Churn_Percentage']):
    ax.text(i, v + 1, f"{v:.1f}%", ha='center')

plt.show()
# Out:
# /tmp/ipykernel_22006/518358751.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=churn_paperless.index, y=churn_paperless['Churn_Percentage'], palette='Set2')

# %%
# Crosstab for churn
churn_senior = pd.crosstab(customer_df['SeniorCitizen'], customer_df['Churn'])
churn_senior['Total'] = churn_senior.sum(axis=1)
churn_senior['Churn_Percentage'] = (churn_senior['Yes'] / churn_senior['Total']) * 100
churn_senior
# Out:
# Churn            No   Yes  Total  Churn_Percentage
# SeniorCitizen
# 0              4508  1393   5901         23.606168
# 1               666   476   1142         41.681261

# %%
plt.figure(figsize=(6,4))
plt.plot(churn_senior.index, churn_senior['Yes'], marker='o', label='Churned')
plt.plot(churn_senior.index, churn_senior['No'], marker='o', label='Stayed')
plt.xticks([0,1], ['Not Senior', 'Senior'])
plt.title('Number of Customers by Senior Citizen Status')
plt.xlabel('Senior Citizen')
plt.ylabel('Number of Customers')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
ax = sns.barplot(x=churn_senior.index, y=churn_senior['Churn_Percentage'], palette='Set1')
plt.title('Churn Percentage by Senior Citizen Status')
plt.xlabel('Senior Citizen')
plt.ylabel('Churn Percentage (%)')
plt.xticks([0,1], ['Not Senior', 'Senior'])

# Add percentages on top of bars
for i, v in enumerate(churn_senior['Churn_Percentage']):
    ax.text(i, v + 1, f"{v:.1f}%", ha='center')

plt.show()
# Out:
# /tmp/ipykernel_22006/2149733902.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=churn_senior.index, y=churn_senior['Churn_Percentage'], palette='Set1')
