# %%
import pandas as pd

# %%
movies_df = pd.read_excel("../MovieDB.xlsx")

# %%
movies_df
# Out:
#                                        Movie Name  \
# 0                                      Foodfight!
# 1                    Superbabies: Baby Geniuses 2
# 2     The Oogieloves in the BIG Balloon Adventure
# 3                  Justin Bieber: Never Say Never
# 4                                  Disaster Movie
# ...                                           ...
# 6156                    The Circus: Down the Road
# 6157                     The Shawshank Redemption
# 6158                                   Redemption
# 6159                                     Brothers
# 6160                                     Brothers
#
#                                      Scraped Name    Budget  \
# 0                                      Foodfight!  45000000
# 1                    Superbabies: Baby Geniuses 2  20000000
# 2     The Oogieloves in the Big Balloon Adventure  20000000
# 3                  Justin Bieber: Never Say Never  13000000
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6161 entries, 0 to 6160
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Movie Name       6161 non-null   object
#  1   Scraped Name     6161 non-null   object
#  2   Budget           6161 non-null   int64
#  3   Director         6161 non-null   object
#  4   Writer           6161 non-null   object
#  5   Actor            6161 non-null   object
#  6   Rating           6161 non-null   float64
#  7   OtherInfo        6161 non-null   object
#  8   Date             6161 non-null   int64
#  9   DirectorsRating  6161 non-null   float64
#  10  WritersRating    6161 non-null   float64
#  11  TotalFollowers   6161 non-null   float64
#  12  Revenue          5958 non-null   float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 625.9+ KB

# %%
movies_df.describe()
# Out:
#              Budget       Rating         Date  DirectorsRating  WritersRating  \
# count  6.161000e+03  6161.000000  6161.000000      6161.000000    6161.000000
# mean   2.893009e+07     6.452524  2004.731537         6.271375       6.189282
# std    3.543593e+07     1.090276    14.180240         1.078598       1.016334
# min    1.000000e+05     1.300000  1911.000000         1.000000       1.000000
# 25%    4.800000e+06     5.800000  2000.000000         6.000000       5.666667
# 50%    1.600000e+07     6.500000  2008.000000         6.333333       6.222222
# 75%    4.000000e+07     7.200000  2014.000000         7.000000       7.000000
# max    1.900000e+08     9.400000  2023.000000         9.000000       9.000000
#
#        TotalFollowers       Revenue
# count     6161.000000  5.958000e+03
# mean        11.456129  8.240365e+07
# std          4.798760  1.494756e+08
# min          0.000000  0.000000e+00
# 25%          8.036669  3.747859e+06
# 50%         11.610660  2.610957e+07
# ...

# %%
movies_df.columns
# Out:
# Index(['Movie Name', 'Scraped Name', 'Budget', 'Director', 'Writer', 'Actor',
#        'Rating', 'OtherInfo', 'Date', 'DirectorsRating', 'WritersRating',
#        'TotalFollowers', 'Revenue'],
#       dtype='object')

# %%
movies_df['Revenue'].isna().sum()
# Out:
# np.int64(203)

# %%
movies_df['TotalFollowers'].isna().sum()
# Out:
# np.int64(0)

# %%
movies_df['OtherInfo'].tail(20)
# Out:
# 6141                         2023\nPG\n2h 20m
# 6142    TV Series\n2006â2007\nTV-14\n23m
# 6143                         2023\nPG\n2h 20m
# 6144                         2023\nPG\n2h 20m
# 6145                          1994\nR\n2h 34m
# 6146    TV Series\n2014â2023\nTV-MA\n53m
# 6147                      2008\nPG-13\n2h 32m
# 6148                      2003\nPG-13\n3h 21m
# 6149                          1993\nR\n3h 15m
# 6150                      2003\nPG-13\n3h 21m
# 6151                          1974\nR\n3h 22m
# 6152                   1957\nApproved\n1h 36m
# 6153                          1972\nR\n2h 55m
# 6154                          1972\nR\n2h 55m
# 6155                             2016\n1h 38m
# 6156                             2016\n1h 38m
# 6157                          1994\nR\n2h 22m
# 6158                          1994\nR\n2h 22m
# 6159      TV Mini Series\n2001\nTV-MA\n9h 54m
# 6160      TV Mini Series\n2001\nTV-MA\n9h 54m
# Name: OtherInfo, dtype: object

# %%
#check for duplicates
movies_df.duplicated().sum()
# Out:
# np.int64(199)

# %%
movies_df = movies_df.drop_duplicates()

# %%
movies_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies_df.dtypes
# Out:
# Movie Name          object
# Scraped Name        object
# Budget               int64
# Director            object
# Writer              object
# Actor               object
# Rating             float64
# OtherInfo           object
# Date                 int64
# DirectorsRating    float64
# WritersRating      float64
# TotalFollowers     float64
# Revenue            float64
# dtype: object

# %%
movies_df['OtherInfo'].sample(20)
# Out:
# 3878        1997\nG\n1h 15m
# 161         2002\nR\n1h 30m
# 2963        2001\nR\n1h 59m
# 3266    2013\nNot Rated\n2h
# 3194    2018\nPG-13\n1h 52m
# 1725        2011\nR\n1h 50m
# 3452    2008\nPG-13\n1h 54m
# 207     2011\nPG-13\n1h 48m
# 2853       2015\nPG\n1h 34m
# 1866       2003\nPG\n1h 41m
# 3695        1999\nR\n1h 37m
# 3416    2008\nPG-13\n1h 55m
# 1207        2011\nR\n1h 53m
# 284     2013\nTV-MA\n1h 26m
# 4447        2017\nR\n1h 53m
# 4220           2018\n1h 32m
# 1398        2010\nR\n1h 22m
# 2422       2005\nPG\n1h 40m
# 927         2002\nR\n1h 33m
# 4255           2018\n1h 41m
# Name: OtherInfo, dtype: object

# %%
movies_df
# Out:
#                                        Movie Name  \
# 0                                      Foodfight!
# 1                    Superbabies: Baby Geniuses 2
# 2     The Oogieloves in the BIG Balloon Adventure
# 3                  Justin Bieber: Never Say Never
# 4                                  Disaster Movie
# ...                                           ...
# 6155                    The Circus: Down the Road
# 6157                     The Shawshank Redemption
# 6158                                   Redemption
# 6159                                     Brothers
# 6160                                     Brothers
#
#                                      Scraped Name    Budget  \
# 0                                      Foodfight!  45000000
# 1                    Superbabies: Baby Geniuses 2  20000000
# 2     The Oogieloves in the Big Balloon Adventure  20000000
# 3                  Justin Bieber: Never Say Never  13000000
# ...

# %%
movies_df.dropna(subset=['Revenue'])
# Out:
#                                        Movie Name  \
# 0                                      Foodfight!
# 1                    Superbabies: Baby Geniuses 2
# 2     The Oogieloves in the BIG Balloon Adventure
# 3                  Justin Bieber: Never Say Never
# 4                                  Disaster Movie
# ...                                           ...
# 6155                    The Circus: Down the Road
# 6157                     The Shawshank Redemption
# 6158                                   Redemption
# 6159                                     Brothers
# 6160                                     Brothers
#
#                                      Scraped Name    Budget  \
# 0                                      Foodfight!  45000000
# 1                    Superbabies: Baby Geniuses 2  20000000
# 2     The Oogieloves in the Big Balloon Adventure  20000000
# 3                  Justin Bieber: Never Say Never  13000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(data=movies_df, x='Budget', y='Revenue')
# Out:
# <Axes: xlabel='Budget', ylabel='Revenue'>

# %%
# Scatter plots
plt.figure(figsize=(10,5))
plt.scatter(movies_df['DirectorsRating'], movies_df['Rating'], alpha=0.5, label='Directors vs Rating')
plt.scatter(movies_df['WritersRating'], movies_df['Rating'], alpha=0.5, label='Writers vs Rating', color='orange')
plt.xlabel('Directors/Writers Rating')
plt.ylabel('Audience Rating')
plt.title('Audience Rating vs Critics Ratings')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(movies_df['Budget'], movies_df['Revenue'], alpha=0.5)
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.title('Revenue vs Budget')
plt.show()

# %%
# Group by year and calculate average budget
budget_by_year = movies_df.groupby('Date')['Budget'].mean()

# Plot
plt.figure(figsize=(12,6))
plt.plot(budget_by_year.index, budget_by_year.values, marker='o', color='purple')
plt.xlabel('Year')
plt.ylabel('Average Budget')
plt.title('Average Movie Budget by Year')
plt.grid(True)
plt.show()

# %%
year_counts = movies_df['Date'].value_counts().sort_index()
plt.figure(figsize=(12,6))
plt.plot(year_counts.index, year_counts.values)
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.title('Movies Released per Year')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(movies_df['Rating'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Number of Movies')
plt.title('Distribution of Audience Ratings')
plt.show()

# %%
top_directors = movies_df.groupby('Director')['Rating'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(10,6))
plt.barh(top_directors.index, top_directors.values, color='green')
plt.xlabel('Average Rating')
plt.title('Top 10 Directors by Average Audience Rating')
plt.gca().invert_yaxis()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(movies_df['Budget'], movies_df['Rating'], alpha=0.6, color='green')
plt.xlabel('Budget')
plt.ylabel('Rating')
plt.title('Movie Budget vs Rating')
plt.grid(True)
plt.show()

# %%
movies_df[['Budget', 'Rating']].corr()
# Out:
#         Budget  Rating
# Budget  1.0000  0.0443
# Rating  0.0443  1.0000

# %%
movies_df.dropna(subset=['Revenue'])
# Out:
#                                        Movie Name  \
# 0                                      Foodfight!
# 1                    Superbabies: Baby Geniuses 2
# 2     The Oogieloves in the BIG Balloon Adventure
# 3                  Justin Bieber: Never Say Never
# 4                                  Disaster Movie
# ...                                           ...
# 6155                    The Circus: Down the Road
# 6157                     The Shawshank Redemption
# 6158                                   Redemption
# 6159                                     Brothers
# 6160                                     Brothers
#
#                                      Scraped Name    Budget  \
# 0                                      Foodfight!  45000000
# 1                    Superbabies: Baby Geniuses 2  20000000
# 2     The Oogieloves in the Big Balloon Adventure  20000000
# 3                  Justin Bieber: Never Say Never  13000000
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=movies_df, x='Budget', y='Revenue')
plt.title('Revenue vs Budget')
plt.xlabel('Budget (USD)')
plt.ylabel('Revenue (USD)')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=movies_df, x='Rating', y='Revenue')
plt.title('Revenue vs IMDb Rating')
plt.xlabel('IMDb Rating')
plt.ylabel('Revenue (USD)')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=movies_df, x='Budget', y='Rating')
plt.title('Budget vs IMDb Rating')
plt.xlabel('Budget (USD)')
plt.ylabel('IMDb Rating')
plt.show()

# %%
numeric_cols = ['Budget', 'Revenue', 'Rating', 'DirectorsRating', 'WritersRating', 'TotalFollowers']
plt.figure(figsize=(10,6))
sns.heatmap(movies_df[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
